# %% [markdown]
# # Copy Inputs

# %%
"""
TODO: In construction
"""
# Out:
# '\n# copy retrieval weights\n!mkdir -p /root/.cache/torch/hub/netvlad\n!cp /kaggle/input/imc-23-weigths/Pitts30K_struct.mat /root/.cache/torch/hub/netvlad/VGG16-NetVLAD-Pitts30K.mat\n!cp -r /kaggle/input/imc-23-weigths/cosplace/gmberton_cosplace_main /root/.cache/torch/hub/gmberton_CosPlace_main\n!cp -r /kaggle/input/imc-23-weigths/cosplace/checkpoints /root/.cache/torch/hub/checkpoints\n\n# copy rotation prediction\n!mkdir -p /root/.cache/huggingface/\n!cp -r /kaggle/input/orientation-prediction-model/hub /root/.cache/huggingface/\n\n# copy run_pixsfm.py script to working directory and make it executable \n!cp /kaggle/input/imc-23-repo/IMC-2023/run_pixsfm.py /kaggle/working/run_pixsfm.py\n!chmod 777 run_pixsfm.py\n\n# copy hloc_reconstruction.py script to working directory and make it executable\n!cp /kaggle/input/imc-23-repo/IMC-2023/hloc_reconstruction.py /kaggle/working/hloc_reconstruction.py\n!chmod 777 hloc_reconstruction.py\n'

# %% [markdown]
# # Install Dependencies

# %%
"""
TODO: In construction
"""
# Out:
# '\n# install hloc\n# %pip install -q /kaggle/input/imc-23-repo/IMC-2023/wheels/hloc-1.3-py3-none-any.whl --no-deps\n\n# install disk deps\n!pip install -q /kaggle/input/imc-23-repo/IMC-2023/wheels/torch_dimcheck-0.0.1-py3-none-any.whl\n!pip install -q /kaggle/input/imc-23-repo/IMC-2023/wheels/unets-0.2.0-py3-none-any.whl\n!pip install -q /kaggle/input/imc-23-repo/IMC-2023/wheels/torch_localize-0.1.0-py3-none-any.whl\n\n# install lightglue deps\n!pip install -q /kaggle/input/imc-23-repo/IMC-2023/wheels/einops-0.6.1-py3-none-any.whl\n\n# install rotation predition\n!pip install -q /kaggle/input/imc-23-repo/IMC-2023/wheels/dioad-1.0.0-py3-none-any.whl\n\n# install ALIKED deps\n!pip install -q /kaggle/input/imc-23-repo/IMC-2023/wheels/thop-0.1.1.post2209072238-py3-none-any.whl --no-deps\n'

# %% [markdown]
# # Run Pipeline

# %%
# Adjust pixsfm config
import yaml
from pathlib import Path
import pixsfm.configs

conf_path = Path(pixsfm.configs.__file__).parent / "low_memory.yaml"


with open(conf_path, 'r') as f:
    conf = yaml.load(f, Loader=yaml.FullLoader)

conf["mapping"]["BA"]["optimizer"]["refine_focal_length"] = True
conf["mapping"]["BA"]["optimizer"]["refine_extra_params"] = True
conf["mapping"]["BA"]["optimizer"]["refine_extrinsics"] = True

out_conf_path = Path("config", "pixsfm.yaml")
out_conf_path.parent.mkdir(exist_ok=True, parents=True)
with open(out_conf_path, 'w') as f:
    yaml.dump(conf, f)

# %%
import argparse
from pathlib import Path
from pixhloc.main import main

args = {
    "data": "./image-matching-challenge-2024",
    "configs": ["SIFT", "ALIKED2K", "DISK"],
    "retrieval": "dinov2_salad",
    "n_retrieval": 30,
    "mode": "train",
    "output": "./temp",
    "pixsfm": True,
    "pixsfm_force": False,
    "pixsfm_max_imgs": 9999,
    "pixsfm_low_mem_threshold": 9999,
    "pixsfm_config": "config/pixsfm.yaml",
    "pixsfm_script_path": "./scripts/run_pixsfm.py",
    "rotation_matching": False,
    "rotation_wrapper": False,
    "resize": None,
    "shared_camera": True,
    "overwrite": True,
    "cropping": False,
    "max_rel_crop_size": 0.75,
    "min_rel_crop_size": 0.2,
    "skip_scenes": None,
    "localize_unregistered": True
}

args = argparse.Namespace(**args)
Path(args.output).mkdir(exist_ok=True)

main(args)
# Out:
# [2024/05/06 00:46:12 root INFO] ================================================================================
# [2024/05/06 00:46:12 root INFO] Arguments:
# [2024/05/06 00:46:12 root INFO] ================================================================================
# [2024/05/06 00:46:12 root INFO]   data: ./image-matching-challenge-2024
# [2024/05/06 00:46:12 root INFO]   configs: ['SIFT', 'ALIKED2K', 'DISK']
# [2024/05/06 00:46:12 root INFO]   retrieval: dinov2_salad
# [2024/05/06 00:46:12 root INFO]   n_retrieval: 30
# [2024/05/06 00:46:12 root INFO]   mode: train
# [2024/05/06 00:46:12 root INFO]   output: ./temp
# [2024/05/06 00:46:12 root INFO]   pixsfm: True
# [2024/05/06 00:46:12 root INFO]   pixsfm_force: False
# [2024/05/06 00:46:12 root INFO]   pixsfm_max_imgs: 9999
# [2024/05/06 00:46:12 root INFO]   pixsfm_low_mem_threshold: 9999
# [2024/05/06 00:46:12 root INFO]   pixsfm_config: config/pixsfm.yaml
# [2024/05/06 00:46:12 root INFO]   pixsfm_script_path: ./scripts/run_pixsfm.py
# [2024/05/06 00:46:12 root INFO]   rotation_matching: False
# [2024/05/06 00:46:12 root INFO]   rotation_wrapper: False
# [2024/05/06 00:46:12 root INFO]   resize: None
# [2024/05/06 00:46:12 root INFO]   shared_camera: True
# [2024/05/06 00:46:12 root INFO]   overwrite: True
# [2024/05/06 00:46:12 root INFO]   cropping: False
# [2024/05/06 00:46:12 root INFO]   max_rel_crop_size: 0.75
# [2024/05/06 00:46:12 root INFO]   min_rel_crop_size: 0.2
# [2024/05/06 00:46:12 root INFO]   skip_scenes: None
# [2024/05/06 00:46:12 root INFO]   localize_unregistered: True
# [2024/05/06 00:46:12 root INFO] ================================================================================
# [2024/05/06 00:46:12 root INFO] DATA:
# [2024/05/06 00:46:12 root INFO] ================================================================================
# [2024/05/06 00:46:12 root INFO] transp_obj_glass_cup
# [2024/05/06 00:46:12 root INFO]   transp_obj_glass_cup: 36 imgs
# [2024/05/06 00:46:12 root INFO] dioscuri
# [2024/05/06 00:46:12 root INFO]   dioscuri: 70 imgs
# [2024/05/06 00:46:12 root INFO] church
# [2024/05/06 00:46:12 root INFO]   church: 111 imgs
# [2024/05/06 00:46:12 root INFO] lizard
# [2024/05/06 00:46:12 root INFO]   lizard: 727 imgs
# [2024/05/06 00:46:12 root INFO] transp_obj_glass_cylinder
# [2024/05/06 00:46:12 root INFO]   transp_obj_glass_cylinder: 36 imgs
# [2024/05/06 00:46:12 root INFO] pond
# [2024/05/06 00:46:12 root INFO]   pond: 1148 imgs
# [2024/05/06 00:46:12 root INFO] multi-temporal-temple-baalshamin
# [2024/05/06 00:46:12 root INFO]   multi-temporal-temple-baalshamin: 75 imgs
# [2024/05/06 00:46:13 root INFO] ================================================================================
# [2024/05/06 00:46:13 root INFO] transp_obj_glass_cup
# [2024/05/06 00:46:13 root INFO] ================================================================================
# [2024/05/06 00:46:13 root INFO] ================================================================================
# [2024/05/06 00:46:13 root INFO] transp_obj_glass_cup - transp_obj_glass_cup
# [2024/05/06 00:46:13 root INFO] ================================================================================
# [2024/05/06 00:46:13 root INFO] Data paths:
# [2024/05/06 00:46:13 root INFO]   input_dir: image-matching-challenge-2024/train/transp_obj_glass_cup
# [2024/05/06 00:46:13 root INFO]   scene_dir: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup
# [2024/05/06 00:46:13 root INFO]   image_dir: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/images
# [2024/05/06 00:46:13 root INFO]   reference_model: None
# [2024/05/06 00:46:13 root INFO]   sfm_dir: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/sparse
# [2024/05/06 00:46:13 root INFO]   pairs_path: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/pairs.txt
# [2024/05/06 00:46:13 root INFO]   features_retrieval: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/features_retrieval.h5
# [2024/05/06 00:46:13 root INFO]   features_path: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/features.h5
# [2024/05/06 00:46:13 root INFO]   matches_path: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/matches.h5
# [2024/05/06 00:46:13 root INFO]   rotated_image_dir: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/images_rotated
# [2024/05/06 00:46:13 root INFO]   rotated_features_path: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/features_rotated.h5
# [2024/05/06 00:46:13 root INFO]   cropping_dir: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/cropping
# [2024/05/06 00:46:13 root INFO]   cropping_pairs_path: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/cropping/pairs.txt
# [2024/05/06 00:46:13 root INFO]   cropping_features_retrieval: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/cropping/features_retrieval.h5
# [2024/05/06 00:46:13 root INFO]   cropping_features_path: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/cropping/features.h5
# [2024/05/06 00:46:13 root INFO]   cropping_matches_path: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/transp_obj_glass_cup/transp_obj_glass_cup/cropping/matches.h5
# [2024/05/06 00:46:13 root INFO]   cache: temp/ALIKED2K+DISK+SIFT-pixsfm-sci-loc/cache
# [2024/05/06 00:46:13 root INFO] ================================================================================
# [2024/05/06 00:46:13 root INFO] Preprocessing
# [2024/05/06 00:46:13 root INFO] ================================================================================
# Rescaling transp_obj_glass_cup: 100%|███████████| 36/36 [00:29<00:00,  1.21it/s]
# [2024/05/06 00:46:43 root INFO] Rotated 0 of 36 images.
# [2024/05/06 00:46:43 root INFO] Images have same shapes: True.
# [2024/05/06 00:46:43 root INFO] ================================================================================
# [2024/05/06 00:46:43 root INFO] Get pairs
# [2024/05/06 00:46:43 root INFO] ================================================================================
# [2024/05/06 00:46:43 hloc INFO] Extracting local features with configuration:
# {'model': {},
#  'output': 'global-feats-dinov2salad',
#  'preprocessing': {'resize_max': 1024}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 33
#      30 args = argparse.Namespace(**args)
#      31 Path(args.output).mkdir(exist_ok=True)
# ---> 33 main(args)
#
# File ~/Workspace/image-matching/imc2024/main.py:159, in main(args)
#     156 # Define and run pipeline
#     157 pipeline = Pipeline(config=config, paths=paths, img_list=img_list, args=args)
# --> 159 pipeline.run()
#     161 sparse_model = pipeline.sparse_model
#     163 if sparse_model is None:
#
# File ~/Workspace/image-matching/imc2024/pipelines/pipeline.py:533, in Pipeline.run(self)
#     528 def run(self) -> None:
#     529     """Run the pipeline."""
#     530     self.timing = {
#     531         "preprocessing": time_function(self.preprocess)(),
#     532         "crop-images": time_function(self.perform_cropping)(),
# --> 533         "pairs-extraction": time_function(self.get_pairs)(),
#     534         "feature-extraction": time_function(self.extract_features)(),
#     535         "feature-matching": time_function(self.match_features)(),
#     536         "create-ensemble": time_function(self.create_ensemble)(),
#     537         "rotate-keypoints": time_function(self.rotate_keypoints)(),
#     538         "sfm": time_function(self.sfm)(),
#     539         "back-rotate-cameras": time_function(self.back_rotate_cameras)(),
#     540         "localize-unreg": time_function(self.localize_unregistered)(),
#     541     }
#
# File ~/Workspace/image-matching/imc2024/pipelines/pipeline.py:39, in time_function.<locals>.wrapper(*args, **kwargs)
#      37 def wrapper(*args, **kwargs):
#      38     start = time.time()
# ---> 39     func(*args, **kwargs)
#      40     return time.time() - start
#
# File ~/Workspace/image-matching/imc2024/pipelines/pipeline.py:166, in Pipeline.get_pairs(self)
#     163     else:
#     164         image_dir = self.paths.image_dir
# --> 166     extract_features.main(
#     167         conf=self.config["retrieval"],
#     168         image_dir=image_dir,
#     169         image_list=self.img_list,
#     170         feature_path=self.paths.features_retrieval,
#     171     )
#     173 pairs_from_retrieval.main(
#     174     descriptors=self.paths.features_retrieval,
#     175     num_matched=self.config["n_retrieval"],
#     176     output=self.paths.pairs_path,
#     177 )
#
# File ~/.venv/image-matching/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Workspace/image-matching/Hierarchical-Localization/hloc/extract_features.py:268, in main(conf, image_dir, export_dir, as_half, image_list, feature_path, overwrite)
#     265     return feature_path
#     267 device = "cuda" if torch.cuda.is_available() else "cpu"
# --> 268 Model = dynamic_load(extractors, conf["model"]["name"])
#     269 model = Model(conf["model"]).eval().to(device)
#     271 loader = torch.utils.data.DataLoader(
#     272     dataset, num_workers=1, shuffle=False, pin_memory=True
#     273 )
#
# KeyError: 'name'
